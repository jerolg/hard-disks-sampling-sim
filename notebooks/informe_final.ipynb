# %% [markdown]
# <div align="center">
#
# # **Técnicas de Muestreo y Simulación de un Sistema de Discos Rígidos**
#
# **Jerónimo López** <sup>[1]</sup>
# *Instituto de Física, Facultad de Ciencias Exactas y Naturales*
# *Universidad de Antioquia, Medellín, Colombia*
#
# ---
# </div>
#
# ### <div align="center">**Resumen**</div>
# <div align="justify">
# En este trabajo se exploran y comparan tres metodologías fundamentales de la física estadística computacional para el estudio de un sistema de discos rígidos en dos dimensiones: el muestreo directo (Direct Sampling), el muestreo basado en cadenas de Markov (MCMC) y la dinámica molecular basada en eventos (EDMD). Se verifica el postulado de equiprobabilidad a priori analizando la frecuencia de microestados específicos y se estudia la distribución espacial de las partículas mediante histogramas de posición. Los resultados permiten comprender la transición entre la descripción puramente estadística y la evolución dinámica de un sistema físico de partículas interactuantes.
# </div>
#
# **Palabras clave:** Discos rígidos, Muestreo directo, Cadenas de Markov, Dinámica molecular por eventos, Equiprobabilidad, Algoritmo de Metropolis.
#
# ---
# </div>

# %% [markdown]
# ## 1.) **Introducción**
#
# - Contextualización del modelo de discos rígidos (es el modelo base para entender transiciones de fase y líquidos).}
#
# - Objetivos del miniproyecto.

# %% [markdown]
# ## 2.) **Marco Teórico**
#
# Aquí debes redactar (usando Markdown y LaTeX) una breve explicación de:
#
# - Postulado de equiprobabilidad a priori.
# - Muestreo Directo (Monte Carlo): Algoritmo de "aceptación-rechazo".
# - Cadenas de Markov (MCMC): Algoritmo de Metropolis local.
# - Dinámica Molecular por Eventos (EDMD): El algoritmo de Alder y Wainwright (explicar qué es un evento y el manejo del tiempo).

# %% [markdown]
# ## 3.) **Resultados y Discusión**
#
# Esta es la parte central donde respondes las preguntas de las diapositivas.
#
# Sección 1: Muestreo Directo (N=4 y N=8)
#
# - Código comentado línea a línea.
# - Respuestas a las preguntas de la pág. 4 (significado de sigma, condition_hit, condition_b).
# - Análisis de la equiprobabilidad según el número de hits para 10^4, 10^5, 10^6 corridas.
#
# Sección 2: Muestreo por Cadenas de Markov
# - Modificación del código y explicación de las líneas 9-14 (pág. 6).
# - Comparación de fluctuaciones vs. Muestreo Directo.
#
# Sección 3: Dinámica Molecular y Eventos
# - Implementación de wall_time y pair_time.
# - Análisis del histograma de posiciones (pág. 10). Punto clave: Explicar por qué no es plano y cómo corregirlo (densidad y exclusión volumétrica).
# - Animación del sistema.

# %%
import random, math

def direct_disks_box(N, sigma):
    condition = False
    while condition == False:
        L = [(random.uniform(sigma, 1.0 - sigma), random.uniform(sigma, 1.0 - sigma))]
        for k in range(1, N):
            a = (random.uniform(sigma, 1.0 - sigma), random.uniform(sigma, 1.0 - sigma))
            min_dist = min(math.sqrt((a[0] - b[0]) ** 2 + (a[1] - b[1]) ** 2) for b in L)
            if min_dist < 2.0 * sigma:
                condition = False
                break
            else:
                L.append(a)
                condition = True
    return L


sigma = 0.15
del_xy = 0.05
n_runs = 10000
conf_a = ((0.30, 0.30), (0.30, 0.70), (0.70, 0.30), (0.70,0.70))
conf_b = ((0.20, 0.20), (0.20, 0.80), (0.75, 0.25), (0.75, 0.75))
conf_c = ((0.30, 0.20), (0.30, 0.80), (0.70, 0.20), (0.70,0.70))
configurations = [conf_a, conf_b, conf_c]
hits = {conf_a: 0, conf_b: 0, conf_c: 0}
#print direct_disks_box(4, sigma)
for run in range(n_runs):
    x_vec = direct_disks_box(4, sigma)
    for conf in configurations:
        condition_hit = True
        for b in conf:
            condition_b = min(max(abs(a[0] - b[0]), abs(a[1] - b[1])) for a in x_vec) < del_xy
            condition_hit *= condition_b
        if condition_hit:
            hits[conf] += 1

for conf in configurations:
    print(conf, hits[conf])
# Out:
# ((0.3, 0.3), (0.3, 0.7), (0.7, 0.3), (0.7, 0.7)) 1
# ((0.2, 0.2), (0.2, 0.8), (0.75, 0.25), (0.75, 0.75)) 1
# ((0.3, 0.2), (0.3, 0.8), (0.7, 0.2), (0.7, 0.7)) 0

# %% [markdown]
# ## 4.) **Conclusiones**

# %% [markdown]
# ## 5.) **Bibliografía**

# %% [markdown]
# **Agradecimientos**
